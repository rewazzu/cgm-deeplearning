# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
style = [":","--","-."]

# %% [markdown]
# ## MAPE vs Prediction Horizon

# %%
df = pd.read_csv("results/mape_vs_horizon.csv",index_col=0)
df
# Out:
#       ARIMA    Linear      LSTM  Transformer
# 15   0.0438  0.047471  0.034957          NaN
# 30   0.0560  0.089541  0.073238          NaN
# 45   0.0768  0.117405  0.099194          NaN
# 60   0.0989  0.143237  0.120799          NaN
# 75   0.1180  0.164226  0.139315          NaN
# 90   0.1340  0.181269  0.158073          NaN
# 105  0.1478  0.197185  0.170177          NaN
# 120  0.1598  0.207268  0.181036          NaN

# %%
df.plot(style=style)
plt.title("MAPE vs Prediction Horizon")
plt.ylabel("MAPE")
plt.xlabel("Prediction Horizon (min)")
plt.ylim(0,0.5)
plt.legend()

# %% [markdown]
# ## MAPE vs Training Patients

# %%
df = pd.read_csv("results/mape_vs_patients.csv",index_col=0)
df
# Out:
#      ARIMA    Linear      LSTM  Transformer
# 1   0.0604  0.181958  0.410881          NaN
# 10  0.0604  0.314173  0.158883          NaN
# 20  0.0604  0.205876  0.137373          NaN
# 30  0.0604  0.144022  0.112948          NaN
# 40  0.0604  0.128021  0.107183          NaN
# 50  0.0604  0.121824  0.103683          NaN
# 60  0.0604  0.119286  0.116574          NaN
# 70  0.0604  0.119622  0.119904          NaN
# 80  0.0604  0.119459  0.114395          NaN
# 90  0.0604  0.117373  0.100130          NaN

# %%
df.plot(style=style)
plt.title("MAPE vs Number of Training Patients")
plt.ylabel("MAPE")
plt.xlabel("Number of Training Patients")
plt.ylim(0,0.5)
plt.legend()
